# %% [markdown]
# # Analyze Supermarket Data Across the Country - Company XYZ
#
# Company XYZ owns a supermarket chain across the country. Each major branch located in 3 cities across the country recorded sales information for 3 months, to help the company understand sales trends and determine its growth, as the rise of supermarkets competition is seen.

# %% [markdown]
# You will apply learnings to analyse the dataset in the data folder, and the description of each feature can be found in this [link](https://docs.google.com/document/d/1Sv-DlynHpOBAs5qKokn5MtbzqZcumTSlSI4-wQ0kf0w/edit?usp=sharing)

# %% [markdown]
# ## Step 1 - Loading the Dataset
# In this step, you will combine the dataset from each branch (3 branches) into one dataset for easy analysis. You expected to write the syntaxes that will read multiple files from your current working directory and export a CSV file after combining.
# The learning from this step is the ability to automate reading and combining multiple CSV files, because as a Data Professional, you will saddled with the responsibility of reading data from different sources, and this is one of the use case.

# %% [markdown]
# #### To-Do - Import Libraries

# %%
import os
import glob
import pandas as pd
os.chdir("C://Users/ugonn/Videos/DS/Ustacky") #Current working directory that contains your dataset and code file

# %% [markdown]
# #### To-Do - Use glob to match the pattern "csv"

# %%
extension = 'csv'
#[Write your Code Here]
all_files = [file for file in glob.glob('*Branch.{}'.format(extension))]

# %% [markdown]
# #### To-Do - Combine all the files in the generated list above and export to a CSV
# Tips - Use the `pd.concat` method

# %%
#[Write your Code Here]
all_csv_files = pd.concat([pd.read_csv(file) for file in all_files])
#Export to csv
#[Write your Code Here]
all_csv_files.to_csv('xyz_company.csv', index=False)

# %% [markdown]
# #### To-Do -Read the CSV file using `pd.read_csv` method

# %%
#[Write your Code Here]
df = pd.read_csv('xyz_company.csv')

# %% [markdown]
# ## Step 2 - Data Exploration
# In this step you will explore the loaded dataset using some built-in Pandas function. You expected to begin to think about your analytical approach from here.
# You can include other methods that you might think will make your exploration process easier. For Instance, you can write a function that print out a summary of the missing data occurence in the data. Be sure to document these methods using `markdown` and in-line `comments`.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### To-Do - Use the head() method to view first few rows of the dataset

# %%
#[Write your Code Here]
df.head(10)
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# 5  371-85-5789      B  Abuja        Normal    Male       Health and beauty
# 6  273-16-6619      B  Abuja        Normal    Male      Home and lifestyle
# 7  649-29-6775      B  Abuja        Normal    Male     Fashion accessories
# 8  145-94-9061      B  Abuja        Normal  Female      Food and beverages
# 9  871-79-8483      B  Abuja        Normal    Male     Fashion accessories
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# ...

# %% [markdown]
# #### To-Do - Check the number of rows and columns present in the data using the shape attribute.

# %%
#[Write your Code Here]
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# #### To-Do - Generate the names of the columns using the columns attribute.

# %%
#[Write your Code Here]
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# #### To-Do - Statiscal Summary
# The describe method provides the data statistical summary for the dataset, use the method to explore the statistical summary.

# %%
#[Write your Code Here]
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905   5536.572840     6.97270
# std                   0.000000   4215.177173     1.71858
# ...

# %% [markdown]
# #### To-Do - Below this cell write in few sentences what you can derive from the data statistical summary

# %% [markdown]
# ### Statistical Summary
# * A standard deviation of zero for the Gross margin percentage means that every customer has the same value.
# * The Tax column is exactly the same as the gross income column.
# * There are no missing values for the numerical columns in this dataset since the count is 1000 for all columns.

# %% [markdown]
# #### To-Do - Missing values
# The `isnull`, and `notna` methods can provide a quick overview of the missing data occurence, use that to observe the presence of missing data in the dataset. You can add the sum method to get a summary and not boolean values.

# %%
#[Write your Code Here]
df.isnull().sum() # No null values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.notna().sum() # No null values
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %% [markdown]
# #### To-Do - Data Information
# The `info()` function is used to print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage. Use this method to observe the data type of each feature.

# %%
#[Write your Code Here]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ## Step 3 - Dealing with DateTime Features

# %% [markdown]
# From the summary above, you can observe that the `date` and `time` columns are not in the appropriate data type
# you can convert to `datetime` datatype using the `to_datetime()` method. After that is done, use the type attribute
# to confirm the datatype.

# %% [markdown]
# #### To-Do - Use `to_datetime()` to convert the `date` column to `datetime`

# %%
#[Write your Code Here]
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# #### To-Do - Check the datatype to confirm if it's in `datetime`

# %%
#[Write your Code Here]
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# #### To-Do - Repeat the two steps above to the `time` column

# %%
#[Write your Code Here]
df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ## Extract Features from date & time

# %% [markdown]
# #### To-Do - Extract the Day feature from the `Date` column, and save to a new `Day` column

# %%
#[Write your Code Here]
df['Day'] = df['Date'].dt.day

# %% [markdown]
# #### To-Do - Extract the Month feature from the `Date` column, and save to a new `Month` column

# %%
#[Write your Code Here]
df['Month'] = df['Date'].dt.month

# %% [markdown]
# #### To-Do -Extract the Year feature from the `Date` column, and save to a new `Year` column

# %%
#[Write your Code Here]
df['Year'] = df['Date'].dt.year

# %% [markdown]
# #### To-Do - Extract the `Hour` feature from the `Time` column and save to a new `Hour` column

# %%
#[Write your Code Here]
df['Hour'] = df['Time'].dt.hour

# %% [markdown]
# #### Pandas provide the `nunique()` method to get a count of unique values, while the `unique()` function is used to get unique values of Series object.

# %% [markdown]
# #### To-Do -  From the hours information, determine the numbers of unique hours of sales in the supermarket, and return an array of the hours using the unique() method

# %%
#[Write your Code Here]
df['Hour'].nunique()
# Out:
# 11

# %%
#[Write your Code Here]
df['Hour'].unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %% [markdown]
# ## Step 4 - Unique Values in Columns

# %% [markdown]
# With the line of code below, we can get a list of the categorical column in the dataset. We iterate through the columns and check if each element is an object datatype. The result is saved to the "categorical_columns" variable
# as a list.

# %%
#Uncomment the code and Run it
categorical_columns = [col for col in df.columns if df[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %% [markdown]
# #### To-Do- From the information above, generate the unique values in the categorical columns (apart from the example - Branch column).
# For example, the unique values of the "Branch" column is displayed in list, as shown below.
# <br/>
# `df['Branch'].unique().tolist()
# ['B', 'C', 'A']`
# </br>
# <br/>
# You can add print formating syntax to print out the total numbers of these values in a particular column.

# %%
#Example - Uncomment the Code and Run it
df['Branch'].unique().tolist()
# Out:
# ['B', 'A', 'C']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Branch'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 3

# %%
#[Write Your Code Here]
for col in categorical_columns:
    if col == 'Branch':
        continue
    else:
        print(f'\n{col}')
        print(df[col].unique().tolist())
        print(f'The total number of unique values in the {col} column is {len(df[col].unique().tolist())}')
# Out:
# Invoice ID
# ...

# %% [markdown]
# #### To-Do: The `value_counts()` function is used to get a Series containing counts of unique values. For the categorical columns above, generate the count figure of the values using the `value_counts() ` method.

# %%
#Example
df['City'].value_counts()
# Out:
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64

# %%
for col in categorical_columns:
    print(f'\n{col}')
    print(df[col].value_counts())
# Out:
# Invoice ID
# 775-72-1988    1
# 735-06-4124    1
# 345-08-4992    1
# 667-23-5919    1
# 751-69-0068    1
#               ..
# 838-78-4295    1
# 549-84-7482    1
# 652-43-6591    1
# 129-29-8530    1
# 686-41-0932    1
# Name: Invoice ID, Length: 1000, dtype: int64
#
# Branch
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64
#
# City
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64
#
# Customer type
# Member    501
# Normal    499
# Name: Customer type, dtype: int64
#
# Gender
# Female    501
# Male      499
# Name: Gender, dtype: int64
#
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64
#
# Payment
# Epay    345
# Cash    344
# Card    311
# Name: Payment, dtype: int64

# %% [markdown]
# ## Step 5 - Aggregration with GroupBy

# %% [markdown]
# #### To-Do - Your task here, will be to create a groupby object with the "City Column", and aggregation function of sum and mean.

# %%
#[Write your Code Here]
df.groupby(['City']).sum()
# Out:
#                Unit price  Quantity      Tax 5%        Total        cogs  \
# City
# Abuja           6652396.8      1820  1820531.52  38231161.92  36410630.4
# Lagos           6705176.4      1859  1820577.78  38232133.38  36411555.6
# Port Harcourt   6684393.6      1831  1895463.54  39804734.34  37909270.8
#
#                gross margin percentage  gross income  Rating   Day  Month  \
# City
# Abuja                      1580.952381    1820531.52  2263.6  5068    665
# Lagos                      1619.047619    1820577.78  2389.2  5232    688
# Port Harcourt              1561.904762    1895463.54  2319.9  4956    640
#
#                  Year  Hour
# City
# Abuja          670308  5029
# Lagos          686460  4987
# Port Harcourt  662232  4894

# %%
df.groupby(['City']).mean()
# Out:
#                  Unit price  Quantity       Tax 5%          Total  \
# City
# Abuja          20037.339759  5.481928  5483.528675  115154.102169
# Lagos          19721.107059  5.467647  5354.640529  112447.451118
# Port Harcourt  20379.248780  5.582317  5778.852256  121355.897378
#
#                         cogs  gross margin percentage  gross income    Rating  \
# City
# Abuja          109670.573494                 4.761905   5483.528675  6.818072
# Lagos          107092.810588                 4.761905   5354.640529  7.027059
# Port Harcourt  115577.045122                 4.761905   5778.852256  7.072866
#
#                      Day     Month    Year       Hour
# City
# Abuja          15.265060  2.003012  2019.0  15.147590
# Lagos          15.388235  2.023529  2019.0  14.667647
# Port Harcourt  15.109756  1.951220  2019.0  14.920732

# %% [markdown]
# #### To-Do - Using the groupby object, display a table that shows the gross income of each city, and determine the city with the highest total gross income.

# %%
#[Write your Code Here]
df.groupby(['City']).agg({'gross income': 'sum'})
# Out:
#                gross income
# City
# Abuja            1820531.52
# Lagos            1820577.78
# Port Harcourt    1895463.54

# %%
# [Write your Answer Here]
print('The city with the highest total gross income is Port Harcourt')
# Out:
# The city with the highest total gross income is Port Harcourt

# %%
# Optional - You can explore other columns such as "Unit Price", "Quantity" etc.
df.groupby(['Quantity']).agg({'Unit price': 'min', 'cogs': 'min'})
# Out:
#           Unit price     cogs
# Quantity
# 1             3661.2   3661.2
# 2             4330.8   8661.6
# 3             3812.4  11437.2
# 4             4960.8  19843.2
# 5             3657.6  18288.0
# 6             4114.8  24688.8
# 7             3628.8  25401.6
# 8             3664.8  29318.4
# 9             4060.8  36547.2
# 10            3945.6  39456.0

# %%
df.groupby(['Quantity']).agg({'Unit price': 'min', 'cogs': 'max'})
# Out:
#           Unit price      cogs
# Quantity
# 1             3661.2   35888.4
# 2             4330.8   71920.8
# 3             3812.4  107676.0
# 4             4960.8  143164.8
# 5             3657.6  179604.0
# 6             4114.8  215827.2
# 7             3628.8  251899.2
# 8             3664.8  286732.8
# 9             4060.8  323870.4
# 10            3945.6  357480.0

# %% [markdown]
# ## Step 6 - Data Visualization

# %% [markdown]
# In this section, you will provide answer to some questions by generating charts and making use of different plotting styles. You will use the `Seaborn visualization` library to generate your plots. For all visualizations, include a chart title by using the seaborn `set_title` method

# %% [markdown]
# #### To-Do- Using `countplot`, determine the branch with the highest sales record. Optional - You can extend this to determine - most used payment method, city with the most sales

# %%
#[Write your Code Here]
sns.countplot(x='Branch', data=df)

# %%
sns.countplot(x='Payment', data=df)

# %%
sns.countplot(x='City', data=df)

# %% [markdown]
# #### Explore a countplot for the `Payment` and `City` Column

# %% [markdown]
# #### To-Do - Determine the highest & lowest sold product line, using Countplot
# Count Plot Tips- Set the `Product line` column to y-axis to prevent congestion on the x-axis

# %%
#[Write your Code Here]
sns.countplot(y='Product line', data=df)

# %% [markdown]
# #### To-Do -  Determine the Payment channel used by most customer to pay for each product line. Count Plot Tips- Set the "product line" column to y-axis to prevent congestion on the x-axis, and use the "hue" parameter for the "Payment" column.

# %%
#[Write your Code Here]
sns.countplot(y='Product line', data=df, hue='Payment')

# %% [markdown]
# #### To-Do- Determine the Payment channel for each branch.
# Count Plot Tips - Use the hue parameter for the "branch" column

# %%
#[Write your Code Here]
sns.countplot(x='Payment', data=df, hue='Branch')

# %% [markdown]
# #### To-Do- Determine the branch with the lowest rating. This you can determine using abox plot which gives a statistical summary of the plotted features, and you can pick out the branch with the lowest rating from the plot

# %%
#[Write your Code Here]
sns.boxplot(x='Branch', y='Rating', data=df)

# %%
#[Write your answer here]
print('All Branches have a minimum rating of 4.0')
# Out:
# All Branches have a minimum rating of 4.0

# %%
df.groupby('Branch').agg({'Rating': 'min'})
# Out:
#         Rating
# Branch
# A          4.0
# B          4.0
# C          4.0

# %% [markdown]
# #### To-Do - The gender type often affects the kind of products being purchased at the supermarket.
# * Using a catplot() generate visualization for the "product line" on x-axis, quantity on the y-axis, and hue as gender.
# <br/>
#
# #### Set the aspect parameter to 4, so can you can effectively space out each product line.
#
#
#
# * Plot the same chart, but `Total Column` as the y-axis
#
# * Write a summary of the insights you can pick from this chart.

# %%
#[Write your Code Here]
sns.catplot(x='Product line', y='Quantity', data=df, hue='Gender', aspect=4, kind='swarm')

# %%
#[Write your Code Here]
sns.catplot(x='Product line', y='Total', data=df, hue='Gender', aspect=4, kind='swarm')

# %% [markdown]
# ## Summary
# * Food and Beverages are mixed between Males and Females.
# * Fashion accessories are dominated by Females as the Quantity goes above 3.
# * Electronic accessories are bought mostly by males for quantities less than 8 and bought mostly by females for quantites between 8 and 10.
# * Sports and travel has more Females in their product line.
# * Home and lifestyle are dominated by Males for quantities less than 6 and Females take over for quantities 6 to 10.
# * Health and beauty have more males in their product line than females.

# %% [markdown]
# #### To-Do -  An interesting insight to explore is the interaction of Unit price on the Quantity of goods purchased. To achieve this:
# * Use the `catplot()` to plot `Product line per unit price`, and `Product line per Quantity`. Set the kind parameter to `point`
# * In a new cell, Write a summary of the insights you uncovered

# %%
#[Write your Code Here]
sns.catplot(x='Quantity', y='Unit price', data=df, kind='point')

# %% [markdown]
# ## Summary
# * Product line bought in the quantity of five has the lowest mean unit price of all other quantities.
# * Product line bought in the quantity of seven has the highest mean unit price of all other quantities.

# %% [markdown]
# ## Step 7 - StandOut Section
# To make your submission standout,
# * You can continue to explore more insights that can be uncovered with different plotting methods.
# * Write a detailed summary on your approach, methods and insights.
# * Visit the [link](https://seaborn.pydata.org/tutorial/categorical.html) for more Seaborn visualization plots.

# %%
df1 = df[ df['Branch'] == 'A' ]

# %%
df2 = df[ df['Branch'] == 'B' ]

# %%
df3 = df[ df['Branch'] == 'C' ]

# %%
df['Rating approx'] = df['Rating'].astype(int)

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total  ... Payment      cogs  \
# 0     19742.4         3   2961.36   62188.56  ...    Card   59227.2
# 1      5212.8         4   1042.56   21893.76  ...    Epay   20851.2
# 2      9183.6         4   1836.72   38571.12  ...    Cash   36734.4
# 3     33739.2         6  10121.76  212556.96  ...    Cash  202435.2
# 4     14508.0         2   1450.80   30466.80  ...    Epay   29016.0
#
#   gross margin percentage  gross income  Rating  Day  Month  Year  Hour  \
# ...

# %% [markdown]
# ### To check customers favorite modes of payment for the different product lines using the catplot method from seaborn

# %%
sns.catplot(x='Product line', hue='Payment', kind='count', data=df2, aspect=4)

# %% [markdown]
# ### Branch B (Abuja)
# * Customers in Branch B (Abuja) rarely use Cash for the Food and Beverages Product line.
# * Cash is the most preferred for Sports and Travel.
# * Epay is the most preferred for Home and lifestyle.

# %%
sns.catplot(x='Product line', hue='Payment', kind='count', data=df1, aspect=4)

# %% [markdown]
# ### Branch A (Lagos)
# * Customers in Branch A (Lagos) rarely use the Card mode of payment for the Home and Lifestyle Product line.
# * Epay is the most preferred for Sports and Travel.
# * Cash is the least favorite in the Fashion and Accessories product line with Epay being the most preferred.

# %%
sns.catplot(x='Product line', hue='Payment', kind='count', data=df3, aspect=4)

# %% [markdown]
# ### Branch C (Port Harcourt)
# * Cash is the most preferred in the Electronic accessories and Food and beverages Product line.
# * Customers here prefer to use the Card mode of payment in the Sports and travel product line.

# %%
sns.catplot(x='Branch', hue='Rating approx', kind='count', data=df, aspect=4)

# %% [markdown]
# ## Summary
# * Branch B gave the highest number of the lowest rating (4) among the three branches and most customers here gave a rating of 6.
# * Branch A has a rating of 7 as the most common rating. Rating 9 is also common.
# * Branch C rated fairly equally between 5 and 9. Rating 4 is significantly smaller here.

# %% [markdown]
# ### To check customers favorite purchasing times for the different product lines using the catplot method from seaborn

# %%
sns.catplot(x='Product line', hue='Hour', kind='count', data=df3, aspect=4)

# %% [markdown]
# ### Branch C (Port Harcourt)
# * Customers purchase Electronic accessories mostly by 11am, 2pm, 3pm and 6pm.
# * Home and lifestyle see increased purchases by 1pm, 5pm and 8pm.
# * Food and Beverages have low purchases between 11am and 2pm, and at 5pm.
# * Sports and travel have their highest purchases by 12pm, 1pm, 4pm and 7pm. There is no sale after 7pm.
# * Health and Beauty have low purchases by 11am, 4pm, 5pm and 8pm.
# * Fashion accessories have low sales by 11am and 6pm.

# %%
sns.catplot(x='Product line', hue='Hour', kind='count', data=df1, aspect=4)

# %% [markdown]
# ### Branch A (Lagos)
# * Electronic accessories have very low purchases by 3pm and 7pm
# * Home and lifestyle have their highest purchases by 1pm and 3pm. Very low purchases occur at 8pm.
# * Food and Beverages have low purchases by 12pm, 2pm and 5pm.
# * Sports and travel have their highest purchases by 10am, 3pm and 4pm.
# * Health and Beauty have their highest purchases by 1pm, 6pm and 8pm.
# * Fashion accessories have very low sales by 10am, 2pm, 7pm and 8pm.

# %%
sns.catplot(x='Product line', hue='Hour', kind='count', data=df2, aspect=4)

# %% [markdown]
# ### Branch B (Abuja)
# * Food and Beverages have no sales by 5pm. Low sales recorded by 11am.
# * Fashion accessories have a very high record of sales by 7pm, and low sales by 12pm, 4pm and 5pm.
# * Electronic accessories recorded low sales by 2pm and 4pm.
# * Sports and Travel have very low sales by 8pm.
# * Home and lifestyle have low sales by 2pm, 4pm and 5pm.
# * Health and beauty recorded high sales by 2pm, and very low sales by 3pm.

# %%
df['Month'].nunique()
# Out:
# 3

# %% [markdown]
# ### To check customers favorite months for the different product lines using the catplot method from seaborn

# %%
sns.catplot(x='Product line', hue='Month', kind='count', data=df3, aspect=4)

# %% [markdown]
# ### Branch C (Port Harcourt)
# * Electronic accessories experience high sales on the Month 3.
# * Home and lifestyle have low sales on the Month 2.
# * Sports and travel have very high sales in Month 1.
# * Health and beauty experience reduced sales in Month 3

# %%
sns.catplot(x='Product line', hue='Month', kind='count', data=df2, aspect=4)

# %% [markdown]
# ### Branch B (Abuja)
# * The Home and lifestyle andd Health and beauty product line experience higher sales in Month 3.
# * The Food and beverages and Fashion and accessories product line experience lower sales in Month 3.

# %%
sns.catplot(x='Product line', hue='Month', kind='count', data=df1, aspect=4)

# %% [markdown]
# ### Branch A (Lagos)
# * The Home and lifestyle and Sports and travel product line experience lower sales in Month 2.
# * Health and Beauty product line has significantly higher sales in Month 3.
# * Food and beverages have lower sales in Month 1.

# %% [markdown]
# ## Step 8 - Documentation.
#
# * Write a detailed `ReadMe` that describes the project, explains important approach you followed to solve the tasks. Find a template in the starter file that can get you started quickly. Note: Do limit yourself to the template, you can include any interesting step that is worth sharing.
# * Write an Executive summary that you can present to `Company XYZ` management. The summary will explain your processes and insights you uncovered that can help the company
